# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import ast
import os

# from IPython.display import display, Markdown
# from pymongo.mongo_client import MongoClient
# from bson.objectid import ObjectId

# %pip install deep-translator
from deep_translator import GoogleTranslator

# %%
# Define the directory containing the CSV files
directory = "csv_backup"

# Initialize an empty list to store DataFrames
dataframes = []

# Loop through all files in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):  # Check if the file is a CSV
        file_path = os.path.join(directory, filename)
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path)
        ### DROP DUPLICATES
        df = df.drop_duplicates()
        dataframes.append(df)

# Combine all DataFrames into a single DataFrame (optional)
data = pd.concat(dataframes)
data.head(3)
# Out:
#                                       ten_cong_viec  \
# 0                      ['Automotive Test Engineer']
# 1                                ['.NET Developer']
# 2  ['Full-stack Developer (Java/.NET/PHP - 3 YOE)']
#
#                                          ten_cong_ty         muc_luong  \
# 0  ['Công ty TNHH Yura Corporation Bắc Ninh_Chi n...                []
# 1              ['CÔNG TY TNHH SAMSUNG SDS VIỆT NAM']  ['Thương lượng']
# 2                             ['Allexceed Việt Nam']  ['Thương lượng']
#
#                                              dia_chi             ngay_dang  \
# 0  ['Tầng 10, tòa nhà Richy, tổ 44, Phường Yên Ho...  ['Đăng 5 giờ trước']
# 1  ['Tòa nhà PVI, số 1 Phạm Văn Bạch, Phường Yên ...  ['Đăng 5 giờ trước']
# 2  ['Tầng 15, Opal Tower, 92 Nguyễn Hữu Cảnh, Phư...  ['Đăng 5 giờ trước']
#
#                nganh_nghe          quy_mo_cong_ty quoc_tich_cong_ty  \
# 0  ['Software, Phần Mềm']  ['Hơn 1000 Nhân viên']         ['Korea']
# 1          ['Dịch vụ IT']  ['Hơn 1000 Nhân viên']   ['South-Korea']
# 2            ['Phần Mềm']     ['25-99 Nhân viên']         ['Japan']
#
#   nam_kinh_nghiem             cap_bac      loai_hinh loai_hop_dong  \
# 0    ['Từ 1 năm']  ['Junior, Middle']  ['In Office']  ['Fulltime']
# 1    ['Từ 6 năm']  ['Middle, Senior']  ['In Office']  ['Fulltime']
# 2    ['Từ 3 năm']  ['Middle, Senior']  ['In Office']  ['Fulltime']
#
#                   cong_nghe_su_dung  \
# 0  ['Tester', 'Test', 'Automotive']
# 1          ['ASP.NET', 'C#', 'Git']
# 2           ['PHP', 'Java', '.NET']
#
#                                  quy_trinh_phong_van  \
# 0  ['Vòng 1: Phỏng vấn qua điện thoại', 'Vòng 2: ...
# 1  ['Vòng 1: CV phù hợp sẽ được liên hệ trong 15 ...
# 2  ['Vòng 1: Phỏng vấn kỹ thuật với team phát tri...
#
#                                      mo_ta_cong_viec  \
# 0  ["Trách nhiệm công việc\nTest cases generation...
# 1  ['Trách nhiệm công việc\nWork for projects to ...
# 2  ['Top 3 reasons to join us\nCơ hội làm việc (n...
#
#                                    thong_tin_cong_ty  \
# 0  Về chúng tôi\nWe at YURA Corporation are recru...
# 1  Về chúng tôi\nSamsung SDS được thành lập năm 1...
# 2  Về chúng tôi\nALLEXCEED VIETNAM (thành lập 201...
#
#                                                  url  \
# 0  https://topdev.vn/viec-lam/automotive-test-eng...
# 1  https://topdev.vn/viec-lam/net-developer-cong-...
# 2  https://topdev.vn/viec-lam/full-stack-develope...
#
#            thoi_gian_hien_tai  \
# 0  2024-11-28 20:55:17.541738
# 1  2024-11-28 20:55:17.541738
# 2  2024-11-28 20:55:17.541738
#
#                                          url_cong_ty
# 0  https://topdev.vn/vi/nha-tuyen-dung/cong-ty-tn...
# 1  https://topdev.vn/nha-tuyen-dung/cong-ty-tnhh-...
# 2  https://topdev.vn/nha-tuyen-dung/allexceed-vie...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11636 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ten_cong_viec        11636 non-null  object
#  1   ten_cong_ty          11636 non-null  object
#  2   muc_luong            11636 non-null  object
#  3   dia_chi              11636 non-null  object
#  4   ngay_dang            11636 non-null  object
#  5   nganh_nghe           11636 non-null  object
#  6   quy_mo_cong_ty       11636 non-null  object
#  7   quoc_tich_cong_ty    11636 non-null  object
#  8   nam_kinh_nghiem      11636 non-null  object
#  9   cap_bac              11636 non-null  object
#  10  loai_hinh            11636 non-null  object
#  11  loai_hop_dong        11636 non-null  object
#  12  cong_nghe_su_dung    11636 non-null  object
#  13  quy_trinh_phong_van  11636 non-null  object
#  14  mo_ta_cong_viec      11636 non-null  object
#  15  thong_tin_cong_ty    11624 non-null  object
#  16  url                  11636 non-null  object
#  17  thoi_gian_hien_tai   11636 non-null  object
#  18  url_cong_ty          11636 non-null  object
# dtypes: object(19)
# memory usage: 1.8+ MB

# %% [markdown]
# # Preprocess

# %%
data["muc_luong"] = data["muc_luong"].replace("[]", "['Thương lượng']")
data["thoi_gian_hien_tai"] = data["thoi_gian_hien_tai"].apply(pd.to_datetime)
for col in data.columns:
    if col in ["thong_tin_cong_ty", "url", "url_cong_ty", "thoi_gian_hien_tai"]:
        continue
    data[col] = data[col].apply(ast.literal_eval)


def getOnlyElement(series):
    return series[0]


for col in data.columns:
    if col in ["thong_tin_cong_ty", "url", "url_cong_ty", "thoi_gian_hien_tai"]:
        continue
    if col in [
        "dia_chi",
        "loai_hinh",
        "loai_hop_dong",
        "cong_nghe_su_dung",
        "quy_trinh_phong_van",
    ]:
        continue
    data[col] = data[col].apply(getOnlyElement)

# %%
def split_(series):
    return series.split(", ")

def castUSA(series):
    return series.replace("USA", "United States")

data["cap_bac"] = data.cap_bac.apply(split_)
data["quoc_tich_cong_ty"] = data.quoc_tich_cong_ty.apply(castUSA).apply(split_)

# %%
def split_domain(series):
    lst = series.split(", ")
    if "Phần Mềm" in lst or "Software" in lst:
        lst = [x for x in lst if x!="Phần Mềm" and x!="Software"]   
        lst.append("Phần Mềm")     
    return lst
data["nganh_nghe"] = data.nganh_nghe.apply(split_domain)

# %%
def experience(series):
    num = re.findall(r"\d+", series)
    if len(num) == 0:
        return 0
    num = num[0]
    if "tháng" in series:
        return int(num) * 1.0 / 12
    if "năm" in series:
        return int(num)
    return pd.NA


data["nam_kinh_nghiem"] = data.nam_kinh_nghiem.apply(experience)

# %%
def size(series):
    if "." in series:
        series = series.replace(".", "")
    num = re.findall(r"\d+", series)
    if len(num) == 0:
        return None
    res = int(num[0])
    if res < 100:
        return "Nhỏ"
    if res < 1000:
        return "Vừa"
    return "Lớn"

data["so_luong_nhan_vien"] = data.quy_mo_cong_ty
data["quy_mo_cong_ty"] = data.quy_mo_cong_ty.apply(size)

# %%
def n_number(series):
    if "." in series:
        series = series.replace(".", "")
    num = re.findall(r"\d+", series)
    if len(num) == 0:
        return [0, 2000000]
    if len(num) == 1:
        return [int(num[0]), 2000000]
    return [int(num[0]), int(num[1])]

data["so_luong_nhan_vien"] = data.so_luong_nhan_vien.apply(n_number)

# %%
def extract_salary_range(salary):
    if salary == "Thương lượng":
        return [0, 0]
    numbers = re.findall(r"[\d.,]+", salary)
    if numbers:
        numbers = [float(num.replace(".", "").strip()) for num in numbers]
        if len(numbers) == 1:
            if numbers[0] > 1_000_000:
                numbers[0] = numbers[0] / 24_000
            return [0, round(numbers[0], 2)]
        for i in range(len(numbers)):
            if numbers[i] > 1_000_000:
                numbers[i] = numbers[i] / 24_000

        # Lấy giá trị nhỏ nhất và lớn nhất
        min_value = min(numbers)
        max_value = max(numbers)

        return [round(min_value, 2), round(max_value, 2)]
    return [0, 0]


data["muc_luong"] = data["muc_luong"].apply(extract_salary_range)

# %%
data.replace("", pd.NA, inplace=True)
data.replace(pd.NA, "Khong co thong tin", inplace=True)

# %% [markdown]
# ## Translate the job title into English

# %%
# 2. Hàm dịch tự động sử dụng Deep Translator
def translate_to_english(text):
    try:
        # Sử dụng Google Translate qua Deep Translator
        translated = GoogleTranslator(source='auto', target='en').translate(text)
        return translated
    except Exception as e:
        print(f"Translation failed for: {text}, Error: {e}")
        return text  # Trả về văn bản gốc nếu dịch lỗi
map_data = data.ten_cong_viec.value_counts().to_frame().reset_index().drop(columns=["count"])
vectorized_func = np.vectorize(translate_to_english)
map_res = vectorized_func(map_data["ten_cong_viec"].to_numpy())

# %%
map_data["translated"] = map_res
map_data = map_data.set_index("ten_cong_viec")
map_dict = map_data["translated"].to_dict()

# %%
def map_translate_result(text):
    try:
        return map_dict[text]
    except:
        print("Error mapping")
        return ""

# 6. Áp dụng hàm vào cột "Job Title"
data['ten_cong_viec'] = data['ten_cong_viec'].apply(map_translate_result)

# 7. In kết quả
data['ten_cong_viec']
# Out:
# 0                               Automotive Test Engineer
# 1                                         .NET Developer
# 2           Full-stack Developer (Java/.NET/PHP - 3 YOE)
# 3                                    Fullstack Developer
# 4      Platform Solution Specialist - Platform Soluti...
#                              ...
# 501                           Senior Front-End Developer
# 502                           Senior Fullstack Developer
# 503    [Urgent] SOFTWARE ENGINEER (C#, Prism Library ...
# 504                       Mobile App Developer (Flutter)
# 505                                      software tester
# Name: ten_cong_viec, Length: 11636, dtype: object

# %% [markdown]
# ## Cluster the jobs from job titles

# %%
# Reusing job group keywords for classification
job_groups = {
    "Management": ["manager", "lead", "coordinator", "scrum", "product owner","administrator","management"],
    "Software/Web/Mobile Development": ["programmer", "coder", "software","web","frontend","backend","game","development","fullstack","dev", "mobile", "ios", "android", "flutter", "react native"],
    "Data & AI": ["data", "ml", "machine learning", "big data", "scientist","ai engineer","ai technical"],
    "Business Analysis":["business analyst","business analysis","business system analyst"],
    "IT Solution & Consulting":["solution","consultant"],
    "QA & Testing": ["qa", "test", "testing", "automation","assurance"],
    "Infrastructure & DevOps": ["devops", "cloud", "system", "administrator", "infrastructure","architect"],
    "Cybersecurity": ["security", "cyber", "pen tester", "forensic", "vulnerability"],
    "Design & UI/UX": ["designer", "ui", "ux", "graphic", "product designer","2D","3D"],
    "Support": ["support", "helpdesk", "service desk"],
    "Other": []
}

# Classify jobs into groups based on keywords
def classify_job(title):
    title_lower = title.lower()
    matched_groups = []
    for group, keywords in job_groups.items():
        if any(keyword in title_lower for keyword in keywords):
            matched_groups.append(group)
    return matched_groups if matched_groups else ["Other"]

job_titles_sample = data["ten_cong_viec"]
# Apply classification to the sample titles
classified_jobs = {title: classify_job(title) for title in job_titles_sample}
data["nhom_cong_viec"] = classified_jobs

# %%
data["nhom_cong_viec"] = data["ten_cong_viec"].apply(classify_job)
data.nhom_cong_viec.explode().value_counts()
# Out:
# nhom_cong_viec
# Software/Web/Mobile Development    5847
# Management                         1946
# Infrastructure & DevOps            1594
# QA & Testing                       1237
# Data & AI                          1155
# Cybersecurity                       620
# IT Solution & Consulting            577
# Business Analysis                   534
# Other                               508
# Support                             358
# Design & UI/UX                      212
# Name: count, dtype: int64

# %%
data.head()
# Out:
#                                        ten_cong_viec  \
# 0                           Automotive Test Engineer
# 1                                     .NET Developer
# 2       Full-stack Developer (Java/.NET/PHP - 3 YOE)
# 3                                Fullstack Developer
# 4  Platform Solution Specialist - Platform Soluti...
#
#                                          ten_cong_ty muc_luong  \
# 0  Công ty TNHH Yura Corporation Bắc Ninh_Chi nhá...    [0, 0]
# 1                  CÔNG TY TNHH SAMSUNG SDS VIỆT NAM    [0, 0]
# 2                                 Allexceed Việt Nam    [0, 0]
# 3                  CÔNG TY TNHH SAMSUNG SDS VIỆT NAM    [0, 0]
# 4                                             MBBANK    [0, 0]
#
#                                              dia_chi         ngay_dang  \
# 0  [Tầng 10, tòa nhà Richy, tổ 44, Phường Yên Hoà...  Đăng 5 giờ trước
# 1  [Tòa nhà PVI, số 1 Phạm Văn Bạch, Phường Yên H...  Đăng 5 giờ trước
# 2  [Tầng 15, Opal Tower, 92 Nguyễn Hữu Cảnh, Phườ...  Đăng 5 giờ trước
# 3  [Tòa nhà PVI, số 1 Phạm Văn Bạch, Phường Yên H...  Đăng 6 giờ trước
# 4  [MB Tower, số 18 Lê Văn Lương, Phường Trung Ho...  Đăng 7 giờ trước
#
#      nganh_nghe quy_mo_cong_ty quoc_tich_cong_ty  nam_kinh_nghiem  \
# 0    [Phần Mềm]            Lớn           [Korea]              1.0
# 1  [Dịch vụ IT]            Lớn     [South-Korea]              6.0
# 2    [Phần Mềm]            Nhỏ           [Japan]              3.0
# 3  [Dịch vụ IT]            Lớn     [South-Korea]              4.0
# 4   [Ngân Hàng]            Lớn         [Vietnam]              0.0
#
#                     cap_bac  ... loai_hop_dong  \
# 0          [Junior, Middle]  ...    [Fulltime]
# 1          [Middle, Senior]  ...    [Fulltime]
# 2          [Middle, Senior]  ...    [Fulltime]
# 3                  [Middle]  ...    [Fulltime]
# 4  [Junior, Middle, Senior]  ...    [Fulltime]
#
#                 cong_nghe_su_dung  \
# 0      [Tester, Test, Automotive]
# 1              [ASP.NET, C#, Git]
# 2               [PHP, Java, .NET]
# 3  [Full-Stack, VueJS, Java Core]
# 4       [Oracle, Database, Kafka]
#
#                                  quy_trinh_phong_van  \
# 0  [Vòng 1: Phỏng vấn qua điện thoại, Vòng 2: Phỏ...
# 1  [Vòng 1: CV phù hợp sẽ được liên hệ trong 15 n...
# 2  [Vòng 1: Phỏng vấn kỹ thuật với team phát triể...
# 3  [Vòng 1: CV phù hợp sẽ được liên hệ trong 15 n...
# 4                                                 []
#
#                                      mo_ta_cong_viec  \
# 0  Trách nhiệm công việc\nTest cases generation b...
# 1  Trách nhiệm công việc\nWork for projects to de...
# 2  Top 3 reasons to join us\nCơ hội làm việc (ngắ...
# 3  Trách nhiệm công việc\nTham gia phát triển và ...
# 4  Trách nhiệm công việc\n Thực hiện việc nghiên ...
#
#                                    thong_tin_cong_ty  \
# 0  Về chúng tôi\nWe at YURA Corporation are recru...
# 1  Về chúng tôi\nSamsung SDS được thành lập năm 1...
# 2  Về chúng tôi\nALLEXCEED VIETNAM (thành lập 201...
# 3  Về chúng tôi\nSamsung SDS được thành lập năm 1...
# 4  Về chúng tôi\nĐược thành lập từ năm 1994, với ...
#
#                                                  url  \
# 0  https://topdev.vn/viec-lam/automotive-test-eng...
# 1  https://topdev.vn/viec-lam/net-developer-cong-...
# 2  https://topdev.vn/viec-lam/full-stack-develope...
# 3  https://topdev.vn/viec-lam/fullstack-developer...
# 4  https://topdev.vn/viec-lam/chuyen-vien-giai-ph...
#
#           thoi_gian_hien_tai  \
# 0 2024-11-28 20:55:17.541738
# 1 2024-11-28 20:55:17.541738
# 2 2024-11-28 20:55:17.541738
# 3 2024-11-28 20:55:17.541738
# 4 2024-11-28 20:55:17.541738
#
#                                          url_cong_ty so_luong_nhan_vien  \
# 0  https://topdev.vn/vi/nha-tuyen-dung/cong-ty-tn...    [1000, 2000000]
# 1  https://topdev.vn/nha-tuyen-dung/cong-ty-tnhh-...    [1000, 2000000]
# 2  https://topdev.vn/nha-tuyen-dung/allexceed-vie...           [25, 99]
# 3  https://topdev.vn/nha-tuyen-dung/cong-ty-tnhh-...    [1000, 2000000]
# 4  https://topdev.vn/nha-tuyen-dung/mbbank-94346?...    [1000, 2000000]
#
#                       nhom_cong_viec
# 0                     [QA & Testing]
# 1  [Software/Web/Mobile Development]
# 2  [Software/Web/Mobile Development]
# 3  [Software/Web/Mobile Development]
# 4         [IT Solution & Consulting]
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11636 entries, 0 to 505
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ten_cong_viec        11636 non-null  object
#  1   ten_cong_ty          11636 non-null  object
#  2   muc_luong            11636 non-null  object
#  3   dia_chi              11636 non-null  object
#  4   ngay_dang            11636 non-null  object
#  5   nganh_nghe           11636 non-null  object
#  6   quy_mo_cong_ty       11636 non-null  object
#  7   quoc_tich_cong_ty    11636 non-null  object
#  8   nam_kinh_nghiem      11636 non-null  float64
#  9   cap_bac              11636 non-null  object
#  10  loai_hinh            11636 non-null  object
#  11  loai_hop_dong        11636 non-null  object
#  12  cong_nghe_su_dung    11636 non-null  object
#  13  quy_trinh_phong_van  11636 non-null  object
#  14  mo_ta_cong_viec      11636 non-null  object
#  15  thong_tin_cong_ty    11636 non-null  object
#  16  url                  11636 non-null  object
#  17  thoi_gian_hien_tai   11636 non-null  datetime64[ns]
#  18  url_cong_ty          11636 non-null  object
#  19  so_luong_nhan_vien   11636 non-null  object
#  20  nhom_cong_viec       11636 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(19)
# memory usage: 2.0+ MB

# %% [markdown]
# # Push to MongoDB Atlas (Cloud Database)

# %%
from IPython.display import display, Markdown
from pymongo.mongo_client import MongoClient
from bson.objectid import ObjectId

# %%
uri = "mongodb+srv://endgame:endgame@cluster0.rkdhc.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command("ping")
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

db = client["udptdltm"]
collection = db["data"]
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# > Check the len of the database before

# %%
object_ids = [doc["_id"] for doc in collection.find({}, {"_id": 1})]
len(object_ids)
# Out:
# 0

# %% [markdown]
# > Push to cloud

# %%
tmp = []
for i in range(data.shape[0]):
    tmp.append(data.iloc[i].to_dict())

collection.insert_many(tmp)
# Out:
# InsertManyResult([ObjectId('675199b702bdf7600cc4da13'), ObjectId('675199b702bdf7600cc4da14'), ObjectId('675199b702bdf7600cc4da15'), ObjectId('675199b702bdf7600cc4da16'), ObjectId('675199b702bdf7600cc4da17'), ObjectId('675199b702bdf7600cc4da18'), ObjectId('675199b702bdf7600cc4da19'), ObjectId('675199b702bdf7600cc4da1a'), ObjectId('675199b702bdf7600cc4da1b'), ObjectId('675199b702bdf7600cc4da1c'), ObjectId('675199b702bdf7600cc4da1d'), ObjectId('675199b702bdf7600cc4da1e'), ObjectId('675199b702bdf7600cc4da1f'), ObjectId('675199b702bdf7600cc4da20'), ObjectId('675199b702bdf7600cc4da21'), ObjectId('675199b702bdf7600cc4da22'), ObjectId('675199b702bdf7600cc4da23'), ObjectId('675199b702bdf7600cc4da24'), ObjectId('675199b702bdf7600cc4da25'), ObjectId('675199b702bdf7600cc4da26'), ObjectId('675199b702bdf7600cc4da27'), ObjectId('675199b702bdf7600cc4da28'), ObjectId('675199b702bdf7600cc4da29'), ObjectId('675199b702bdf7600cc4da2a'), ObjectId('675199b702bdf7600cc4da2b'), ObjectId('675199b702bdf7600cc4da2c'), ObjectId('675199b702bdf7600cc4da2d'), ObjectId('675199b702bdf7600cc4da2e'), ObjectId('675199b702bdf7600cc4da2f'), ObjectId('675199b702bdf7600cc4da30'), ObjectId('675199b702bdf7600cc4da31'), ObjectId('675199b702bdf7600cc4da32'), ObjectId('675199b702bdf7600cc4da33'), ObjectId('675199b702bdf7600cc4da34'), ObjectId('675199b702bdf7600cc4da35'), ObjectId('675199b702bdf7600cc4da36'), ObjectId('675199b702bdf7600cc4da37'), ObjectId('675199b702bdf7600cc4da38'), ObjectId('675199b702bdf7600cc4da39'), ObjectId('675199b702bdf7600cc4da3a'), ObjectId('675199b702bdf7600cc4da3b'), ObjectId('675199b702bdf7600cc4da3c'), ObjectId('675199b702bdf7600cc4da3d'), ObjectId('675199b702bdf7600cc4da3e'), ObjectId('675199b702bdf7600cc4da3f'), ObjectId('675199b702bdf7600cc4da40'), ObjectId('675199b702bdf7600cc4da41'), ObjectId('675199b702bdf7600cc4da42'), ObjectId('675199b702bdf7600cc4da43'), ObjectId('675199b702bdf7600cc4da44'), ObjectId('675199b702bdf7600cc4da45'), ObjectId('675199b702bdf7600cc4da46'), ObjectId('675199b702bdf7600cc4da47'), ObjectId('675199b702bdf7600cc4da48'), ObjectId('675199b702bdf7600cc4da49'), ObjectId('675199b702bdf7600cc4da4a'), ObjectId('675199b702bdf7600cc4da4b'), ObjectId('675199b702bdf7600cc4da4c'), ObjectId('675199b702bdf7600cc4da4d'), ObjectId('675199b702bdf7600cc4da4e'), ObjectId('675199b702bdf7600cc4da4f'), ObjectId('675199b702bdf7600cc4da50'), ObjectId('675199b702bdf7600cc4da51'), ObjectId('675199b702bdf7600cc4da52'), ObjectId('675199b702bdf7600cc4da53'), ObjectId('675199b702bdf7600cc4da54'), ObjectId('675199b702bdf7600cc4da55'), ObjectId('675199b702bdf7600cc4da56'), ObjectId('675199b702bdf7600cc4da57'), ObjectId('675199b702bdf7600cc4da58'), ObjectId('675199b702bdf7600cc4da59'), ObjectId('675199b702bdf7600cc4da5a'), ObjectId('675199b702bdf7600cc4da5b'), ObjectId('675199b702bdf7600cc4da5c'), ObjectId('675199b702bdf7600cc4da5d'), ObjectId('675199b702bdf7600cc4da5e'), ObjectId('675199b702bdf7600cc4da5f'), ObjectId('675199b702bdf7600cc4da60'), ObjectId('675199b702bdf7600cc4da61'), ObjectId('675199b702bdf7600cc4da62'), ObjectId('675199b702bdf7600cc4da63'), ObjectId('675199b702bdf7600cc4da64'), ObjectId('675199b702bdf7600cc4da65'), ObjectId('675199b702bdf7600cc4da66'), ObjectId('675199b702bdf7600cc4da67'), ObjectId('675199b702bdf7600cc4da68'), ObjectId('675199b702bdf7600cc4da69'), ObjectId('675199b702bdf7600cc4da6a'), ObjectId('675199b702bdf7600cc4da6b'), ObjectId('675199b702bdf7600cc4da6c'), ObjectId('675199b702bdf7600cc4da6d'), ObjectId('675199b702bdf7600cc4da6e'), ObjectId('675199b702bdf7600cc4da6f'), ObjectId('675199b702bdf7600cc4da70'), ObjectId('675199b702bdf7600cc4da71'), ObjectId('675199b702bdf7600cc4da72'), ObjectId('675199b702bdf7600cc4da73'), ObjectId('675199b702bdf7600cc4da74'), ObjectId('675199b702bdf7600cc4da75'), ObjectId('675199b702bdf7600cc4da76'), ObjectId('675199b702bdf7600cc4da77'), ObjectId('675199b702bdf7600cc4da78'), ObjectId('675199b702bdf7600cc4da79'), ObjectId('675199b702bdf7600cc4da7a'), ObjectId('675199b702bdf7600cc4 ...

# %% [markdown]
# > Check the len of the database after

# %%
object_ids = [doc["_id"] for doc in collection.find({}, {"_id": 1})]
len(object_ids)
# Out:
# 11636

# %%
collection.distinct("thoi_gian_hien_tai")
# Out:
# [datetime.datetime(2024, 10, 29, 23, 49, 40, 410000),
#  datetime.datetime(2024, 10, 30, 21, 12, 27, 898000),
#  datetime.datetime(2024, 10, 31, 22, 31, 43, 598000),
#  datetime.datetime(2024, 11, 1, 18, 57, 33, 986000),
#  datetime.datetime(2024, 11, 2, 21, 31, 49, 226000),
#  datetime.datetime(2024, 11, 3, 21, 38, 30),
#  datetime.datetime(2024, 11, 4, 22, 16, 5, 607000),
#  datetime.datetime(2024, 11, 5, 21, 36, 12, 594000),
#  datetime.datetime(2024, 11, 6, 22, 21, 3, 196000),
#  datetime.datetime(2024, 11, 7, 21, 16, 27, 26000),
#  datetime.datetime(2024, 11, 8, 21, 29, 37, 990000),
#  datetime.datetime(2024, 11, 9, 22, 2, 25, 48000),
#  datetime.datetime(2024, 11, 10, 20, 31, 45, 149000),
#  datetime.datetime(2024, 11, 11, 14, 20, 13, 537000),
#  datetime.datetime(2024, 11, 12, 21, 37, 52, 656000),
#  datetime.datetime(2024, 11, 13, 13, 39, 32, 143000),
#  datetime.datetime(2024, 11, 14, 14, 45, 15, 444000),
#  datetime.datetime(2024, 11, 15, 21, 20, 17, 292000),
#  datetime.datetime(2024, 11, 16, 20, 54, 43, 495000),
#  datetime.datetime(2024, 11, 17, 21, 55, 19, 72000),
#  datetime.datetime(2024, 11, 18, 22, 27, 2, 468000),
#  datetime.datetime(2024, 11, 19, 21, 47, 19, 572000),
#  datetime.datetime(2024, 11, 20, 21, 33, 28, 6000),
#  datetime.datetime(2024, 11, 21, 21, 37, 42, 229000),
#  datetime.datetime(2024, 11, 22, 22, 20, 46, 415000),
#  datetime.datetime(2024, 11, 23, 21, 26, 46, 48000),
#  datetime.datetime(2024, 11, 24, 23, 46, 54, 600000),
#  datetime.datetime(2024, 11, 25, 22, 23, 41, 205000),
#  datetime.datetime(2024, 11, 26, 22, 19, 4, 541000),
#  datetime.datetime(2024, 11, 27, 21, 15, 26, 441000),
#  datetime.datetime(2024, 11, 28, 20, 55, 17, 541000),
#  datetime.datetime(2024, 11, 29, 21, 57, 1, 42000),
#  datetime.datetime(2024, 11, 30, 23, 58, 53, 998000),
#  datetime.datetime(2024, 12, 1, 20, 32, 28, 498000),
#  datetime.datetime(2024, 12, 2, 22, 24, 5, 29000),
#  datetime.datetime(2024, 12, 3, 21, 28, 28, 210000),
#  datetime.datetime(2024, 12, 4, 20, 53, 14, 194000)]

# %%
df = data.drop_duplicates(subset="url", keep="first").reset_index(drop=True)
df.to_csv("processed_data.csv", index=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ten_cong_viec        521 non-null    object
#  1   ten_cong_ty          521 non-null    object
#  2   muc_luong            521 non-null    object
#  3   dia_chi              521 non-null    object
#  4   ngay_dang            521 non-null    object
#  5   nganh_nghe           521 non-null    object
#  6   quy_mo_cong_ty       521 non-null    object
#  7   quoc_tich_cong_ty    521 non-null    object
#  8   nam_kinh_nghiem      521 non-null    float64
#  9   cap_bac              521 non-null    object
#  10  loai_hinh            521 non-null    object
#  11  loai_hop_dong        521 non-null    object
#  12  cong_nghe_su_dung    521 non-null    object
#  13  quy_trinh_phong_van  521 non-null    object
#  14  mo_ta_cong_viec      521 non-null    object
#  15  thong_tin_cong_ty    521 non-null    object
#  16  url                  521 non-null    object
#  17  thoi_gian_hien_tai   521 non-null    datetime64[ns]
#  18  url_cong_ty          521 non-null    object
#  19  so_luong_nhan_vien   521 non-null    object
#  20  nhom_cong_viec       521 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(19)
# memory usage: 85.6+ KB
